# %% [markdown]
# # Coursework for MRI reconstruction (Autumn 2019)
#
# In this tutorial, we provide the data loader to read and process the MRI data in order to ease the difficulty of training your network. By providing this, we hope you focus more on methodology development. Please feel free to change it to suit what you need.

# %% [raw]
# Introduction

# %%
#ALL IMPORTS
import h5py, os
from functions import transforms as T
from functions.subsample import MaskFunc
from scipy.io import loadmat
from torch.utils.data import DataLoader
import numpy as np
import torch
from matplotlib import pyplot as plt
from torch import nn
from torch.nn import functional as F
from matplotlib import pyplot as plt

# %% [raw]
# The Unet model below created by MIT, and was used in the assignment as a platform to build the neural network. https://github.com/facebookresearch/fastMRI.git

# %%
##### UNET MODEL ######

class ConvBlock(nn.Module):
    """
    A Convolutional Block that consists of two convolution layers each followed by
    instance normalization, relu activation and dropout.
    """

    def __init__(self, in_chans, out_chans, drop_prob):
        """
        Args:
            in_chans (int): Number of channels in the input.
            out_chans (int): Number of channels in the output.
            drop_prob (float): Dropout probability.
        """
        super().__init__()

        self.in_chans = in_chans
        self.out_chans = out_chans
        self.drop_prob = drop_prob

        self.layers = nn.Sequential(
            nn.Conv2d(in_chans, out_chans, kernel_size=3, padding=1),
            nn.InstanceNorm2d(out_chans),
            nn.ReLU(),
            nn.Dropout2d(drop_prob),
            nn.Conv2d(out_chans, out_chans, kernel_size=3, padding=1),
            nn.InstanceNorm2d(out_chans),
            nn.ReLU(),
            nn.Dropout2d(drop_prob)
        )

    def forward(self, input):
        """
        Args:
            input (torch.Tensor): Input tensor of shape [batch_size, self.in_chans, height, width]

        Returns:
            (torch.Tensor): Output tensor of shape [batch_size, self.out_chans, height, width]
        """
        return self.layers(input)

    def __repr__(self):
        return f'ConvBlock(in_chans={self.in_chans}, out_chans={self.out_chans}, ' \
            f'drop_prob={self.drop_prob})'


class UnetModel(nn.Module):
    """
    PyTorch implementation of a U-Net model.

    This is based on:
        Olaf Ronneberger, Philipp Fischer, and Thomas Brox. U-net: Convolutional networks
        for biomedical image segmentation. In International Conference on Medical image
        computing and computer-assisted intervention, pages 234–241. Springer, 2015.
    """

    def __init__(self, in_chans, out_chans, chans, num_pool_layers, drop_prob):
        """
        Args:
            in_chans (int): Number of channels in the input to the U-Net model.
            out_chans (int): Number of channels in the output to the U-Net model.
            chans (int): Number of output channels of the first convolution layer.
            num_pool_layers (int): Number of down-sampling and up-sampling layers.
            drop_prob (float): Dropout probability.
        """
        super().__init__()

        self.in_chans = in_chans
        self.out_chans = out_chans
        self.chans = chans
        self.num_pool_layers = num_pool_layers
        self.drop_prob = drop_prob

        self.down_sample_layers = nn.ModuleList([ConvBlock(in_chans, chans, drop_prob)])
        ch = chans
        for i in range(num_pool_layers - 1):
            self.down_sample_layers += [ConvBlock(ch, ch * 2, drop_prob)]
            ch *= 2
        self.conv = ConvBlock(ch, ch, drop_prob)

        self.up_sample_layers = nn.ModuleList()
        for i in range(num_pool_layers - 1):
            self.up_sample_layers += [ConvBlock(ch * 2, ch // 2, drop_prob)]
            ch //= 2
        self.up_sample_layers += [ConvBlock(ch * 2, ch, drop_prob)]
        self.conv2 = nn.Sequential(
            nn.Conv2d(ch, ch // 2, kernel_size=1),
            nn.Conv2d(ch // 2, out_chans, kernel_size=1),
            nn.Conv2d(out_chans, out_chans, kernel_size=1),
        )

    def forward(self, input):
        """
        Args:
            input (torch.Tensor): Input tensor of shape [batch_size, self.in_chans, height, width]

        Returns:
            (torch.Tensor): Output tensor of shape [batch_size, self.out_chans, height, width]
        """
        stack = []
        output = input
        # Apply down-sampling layers
        for layer in self.down_sample_layers:
            output = layer(output)
            stack.append(output)
            output = F.max_pool2d(output, kernel_size=2)

        output = self.conv(output)

        # Apply up-sampling layers
        for layer in self.up_sample_layers:
            output = F.interpolate(output, scale_factor=2, mode='bilinear', align_corners=False)
            output = torch.cat([output, stack.pop()], dim=1)
            output = layer(output)
        return self.conv2(output)

# %%
#pre-defined ultily functions used in creating the neural net

def show_slices(data, slice_nums, cmap=None): # visualisation
    fig = plt.figure(figsize=(15,10))
    for i, num in enumerate(slice_nums):
        plt.subplot(1, len(slice_nums), i + 1)
        plt.imshow(data[num], cmap=cmap)
        plt.axis('off')

def get_epoch_batch(subject_id, acc, center_fract, use_seed=True):
    ''' random select a few slices (batch_size) from each volume'''

    fname, rawdata_name, slice = subject_id  
    
    with h5py.File(rawdata_name, 'r') as data:
        rawdata = data['kspace'][slice]
                      
    slice_kspace = T.to_tensor(rawdata).unsqueeze(0)
    S, Ny, Nx, ps = slice_kspace.shape

    # apply random mask
    shape = np.array(slice_kspace.shape)
    mask_func = MaskFunc(center_fractions=[center_fract], accelerations=[acc])
    seed = None if not use_seed else tuple(map(ord, fname))
    mask = mask_func(shape, seed)
      
    # undersample
    masked_kspace = torch.where(mask == 0, torch.Tensor([0]), slice_kspace)
    masks = mask.repeat(S, Ny, 1, ps)

    img_gt, img_und = T.ifft2(slice_kspace), T.ifft2(masked_kspace)

    # perform data normalization which is important for network to learn useful features
    # during inference there is no ground truth image so use the zero-filled recon to normalize
    norm = T.complex_abs(img_und).max()
    if norm < 1e-6: norm = 1e-6
    
#     A = cropped_img_und.squeeze().detach().cpu()
#     C = cropped_gt.squeeze().squeeze().detach().cpu()
    
    # normalized data
    img_gt, img_und, rawdata_und = img_gt/norm, img_und/norm, masked_kspace/norm
    
    volume_image_abs = T.complex_abs(img_gt) 
    cropped_gt = T.center_crop(volume_image_abs, [320, 320])
    cropped_gt = cropped_gt
        
    volume_image_abs = T.complex_abs(img_und) 
    cropped_img_und = T.center_crop(volume_image_abs, [320, 320])
    cropped_img_und = cropped_img_und
        
    return cropped_gt,cropped_img_und, norm
  #return img_gt.squeeze(0), img_und.squeeze(0), rawdata_und.squeeze(0), masks.squeeze(0), norm

class MRIDataset(DataLoader):
    def __init__(self, data_list, acceleration, center_fraction, use_seed):
        self.data_list = data_list
        self.acceleration = acceleration
        self.center_fraction = center_fraction
        self.use_seed = use_seed

    def __len__(self):
        return len(self.data_list)

    def __getitem__(self, idx):
        subject_id = self.data_list[idx]
        return get_epoch_batch(subject_id, self.acceleration, self.center_fraction, self.use_seed)
    
    def load_data_path(train_data_path, val_data_path):
        """ Go through each subset (training, validation) and list all 
        the file names, the file paths and the slices of subjects in the training and validation sets 
        """

        data_list = {}
        train_and_val = ['train', 'val']
        data_path = [train_data_path, val_data_path]

        for i in range(len(data_path)):

            data_list[train_and_val[i]] = []

            which_data_path = data_path[i]

            for fname in sorted(os.listdir(which_data_path)):

                subject_data_path = os.path.join(which_data_path, fname)

                if not os.path.isfile(subject_data_path): continue 

                with h5py.File(subject_data_path, 'r') as data:
                    num_slice = data['kspace'].shape[0]

                # the first 5 slices are mostly noise so it is better to exlude them
                data_list[train_and_val[i]] += [(fname, subject_data_path, slice) for slice in range(5, num_slice)]

        return data_list  
   
    
from skimage.measure import compare_ssim  
def ssim(gt, pred):
    """ Compute Structural Similarity Index Metric (SSIM). """
    return compare_ssim(
        gt.transpose(1, 2, 0), pred.transpose(1, 2, 0), multichannel=True, data_range=gt.max()
    )  


def show_slices(data, slice_nums, cmap=None): # visualisation
    fig = plt.figure(figsize=(15,10))
    for i, num in enumerate(slice_nums):
        plt.subplot(1, len(slice_nums), i + 1)
        plt.imshow(data[num], cmap=cmap)
        plt.axis('off')

# %% [raw]
# During the iterative cycle of training, the model may begin to overfit the model, rendering it ineffective to
#
# The a validation set is created in order to ensure the model is not "over fitting" the training data. An

# %%
#Set initial path for the fullset of training data
file_path = '/data/local/NC2019MRI/train'

# Shuffle sets, and split train_index into train and validation 80:20 respectively 
numfiles_all = len(os.listdir(file_path))
print (numfiles_all)
indx = np.arange(numfiles_all)
np.random.shuffle(indx)

split_80_20 = 0.8 * numfiles_all
split_80_20 = int(split_80_20)
print(split_80_20)

np.random.seed(42)

train_inx = indx[:split_80_20]
val_inx = indx[split_80_20:]

print("train_inx",train_inx)
print("val_inx",val_inx)
# Out:
# 70
# 56
# train_inx [10 23 48 51 36 62 57 24 26 42 58 38  4 44 59 13 30 31 68 22  1 50 21 47
#   8 43 32 60 11 66 37 61 41 54 45 15 28  2 63 52 19  6 17  9 40 46  0 39
#  12  3 55 18 20  5 29 69]
# val_inx [16 64 35 65 67 25 53 49 33 56  7 27 14 34]

# %%
    train_data_list = {}
    train_data_list['val']= [0] * len(val_inx)
    train_data_list['train'] = [0] * len(train_inx)
    count = 0  
    
    for fname in sorted(os.listdir(file_path)): 
        subject_path = os.path.join(file_path, fname)
        with h5py.File(subject_path,  "r") as hf:
             total_num_slices = hf['kspace'].shape[0]

                
        for i in range(len(train_inx)):
            if (train_inx[i] == count):
                train_data_list['train'][i] = (file_path+ "/" +fname, fname, total_num_slices)  
                break
                
        for k in range(len(val_inx)):
            if (val_inx[k] == count):
                train_data_list['val'][k] = (file_path+ "/"+ fname, fname, total_num_slices)
                break
        count = count +1

            
    train_data_final ={}         
    train_data_final['train'] = []  
    train_data_final['val'] = []  
           
    for i in range (len(train_data_list['train'])):
        for slice in range (5,train_data_list['train'][i][2]):
            train_data_final['train'].append((train_data_list['train'][i][1], train_data_list['train'][i][0], (slice)))
        

    for i in range (len(train_data_list['val'])):
        for slice in range (5,train_data_list['val'][i][2]):
            train_data_final['val'].append((train_data_list['val'][i][1], train_data_list['val'][i][0], slice))

# %%
print("VALIDATION SET")
valcount = 0
for i in range (len(train_data_final['val'])):
    print(" count : ",valcount,"  ", train_data_final['val'][i])
    valcount = valcount + 1
    
print("")
print("")
print("")
print("")

train_count = 0    
print("TRAIN SET")
for i in range (len(train_data_final['train'])):
    print(" count : ",train_count,"  ", train_data_final['train'][i])
    train_count = train_count + 1
# Out:
# VALIDATION SET
#  count :  0    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 5)
#  count :  1    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 6)
#  count :  2    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 7)
#  count :  3    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 8)
#  count :  4    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 9)
#  count :  5    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 10)
#  count :  6    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 11)
#  count :  7    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 12)
#  count :  8    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 13)
#  count :  9    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 14)
#  count :  10    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 15)
#  count :  11    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 16)
#  count :  12    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 17)
#  count :  13    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 18)
#  count :  14    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 19)
#  count :  15    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 20)
#  count :  16    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 21)
#  count :  17    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 22)
#  count :  18    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 23)
#  count :  19    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 24)
#  count :  20    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 25)
#  count :  21    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 26)
#  count :  22    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 27)
#  count :  23    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 28)
#  count :  24    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 29)
#  count :  25    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 30)
#  count :  26    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 31)
#  count :  27    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 32)
#  count :  28    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 33)
#  count :  29    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 34)
#  count :  30    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 35)
#  count :  31    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 36)
#  count :  32    ('file1000182.h5', '/data/local/NC2019MRI/train/file1000182.h5', 37)
#  count :  33    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 5)
#  count :  34    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 6)
#  count :  35    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 7)
#  count :  36    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 8)
#  count :  37    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 9)
#  count :  38    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 10)
#  count :  39    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 11)
#  count :  40    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 12)
#  count :  41    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 13)
#  count :  42    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 14)
#  count :  43    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 15)
#  count :  44    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 16)
#  count :  45    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 17)
#  count :  46    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 18)
#  count :  47    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 19)
#  count :  48    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 20)
#  count :  49    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 21)
#  count :  50    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 22)
#  count :  51    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 23)
#  count :  52    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 24)
#  count :  53    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 25)
#  count :  54    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 26)
#  count :  55    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 27)
#  count :  56    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 28)
#  count :  57    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 29)
#  count :  58    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 30)
#  count :  59    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 31)
#  count :  60    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 32)
#  count :  61    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 33)
#  count :  62    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 34)
#  count :  63    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 35)
#  count :  64    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 36)
#  count :  65    ('file1000735.h5', '/data/local/NC2019MRI/train/file1000735.h5', 37)
#  count :  66    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 5)
#  count :  67    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 6)
#  count :  68    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 7)
#  count :  69    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 8)
#  count :  70    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 9)
#  count :  71    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 10)
#  count :  72    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 11)
#  count :  73    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 12)
#  count :  74    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 13)
#  count :  75    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 14)
#  count :  76    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 15)
#  count :  77    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 16)
#  count :  78    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 17)
#  count :  79    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 18)
#  count :  80    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 19)
#  count :  81    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 20)
#  count :  82    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 21)
#  count :  83    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 22)
#  count :  84    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 23)
#  count :  85    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 24)
#  count :  86    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 25)
#  count :  87    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 26)
#  count :  88    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 27)
#  count :  89    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 28)
#  count :  90    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 29)
#  count :  91    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 30)
#  count :  92    ('file1000314.h5', '/data/local/NC2019MRI/train/file1000314.h5', 31)
#  count :  93    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 5)
#  count :  94    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 6)
#  count :  95    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 7)
#  count :  96    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 8)
#  count :  97    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 9)
#  count :  98    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 10)
#  count :  99    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 11)
#  count :  100    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 12)
#  count :  101    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 13)
#  count :  102    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 14)
#  count :  103    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 15)
#  count :  104    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 16)
#  count :  105    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 17)
#  count :  106    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 18)
#  count :  107    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 19)
#  count :  108    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 20)
#  count :  109    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 21)
#  count :  110    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 22)
#  count :  111    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 23)
#  count :  112    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 24)
#  count :  113    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 25)
#  count :  114    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 26)
#  count :  115    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 27)
#  count :  116    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 28)
#  count :  117    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 29)
#  count :  118    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 30)
#  count :  119    ('file1000748.h5', '/data/local/NC2019MRI/train/file1000748.h5', 31)
#  count :  120    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 5)
#  count :  121    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 6)
#  count :  122    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 7)
#  count :  123    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 8)
#  count :  124    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 9)
#  count :  125    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 10)
#  count :  126    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 11)
#  count :  127    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 12)
#  count :  128    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 13)
#  count :  129    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 14)
#  count :  130    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 15)
#  count :  131    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 16)
#  count :  132    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 17)
#  count :  133    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 18)
#  count :  134    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 19)
#  count :  135    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 20)
#  count :  136    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 21)
#  count :  137    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 22)
#  count :  138    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 23)
#  count :  139    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 24)
#  count :  140    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 25)
#  count :  141    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 26)
#  count :  142    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 27)
#  count :  143    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 28)
#  count :  144    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 29)
#  count :  145    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 30)
#  count :  146    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 31)
#  count :  147    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 32)
#  count :  148    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 33)
#  count :  149    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 34)
#  count :  150    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 35)
#  count :  151    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 36)
#  count :  152    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 37)
#  count :  153    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 38)
#  count :  154    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 39)
#  count :  155    ('file1000759.h5', '/data/local/NC2019MRI/train/file1000759.h5', 40)
#  count :  156    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 5)
#  count :  157    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 6)
#  count :  158    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 7)
#  count :  159    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 8)
#  count :  160    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 9)
#  count :  161    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 10)
#  count :  162    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 11)
#  count :  163    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 12)
#  count :  164    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 13)
#  count :  165    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 14)
#  count :  166    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 15)
#  count :  167    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 16)
#  count :  168    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 17)
#  count :  169    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 18)
#  count :  170    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 19)
#  count :  171    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 20)
#  count :  172    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 21)
#  count :  173    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 22)
#  count :  174    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 23)
#  count :  175    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 24)
#  count :  176    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 25)
#  count :  177    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 26)
#  count :  178    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 27)
#  count :  179    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 28)
#  count :  180    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 29)
#  count :  181    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 30)
#  count :  182    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 31)
#  count :  183    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 32)
#  count :  184    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 33)
#  count :  185    ('file1000263.h5', '/data/local/NC2019MRI/train/file1000263.h5', 34)
#  count :  186    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 5)
#  count :  187    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 6)
#  count :  188    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 7)
#  count :  189    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 8)
#  count :  190    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 9)
#  count :  191    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 10)
#  count :  192    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 11)
#  count :  193    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 12)
#  count :  194    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 13)
#  count :  195    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 14)
#  count :  196    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 15)
#  count :  197    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 16)
#  count :  198    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 17)
#  count :  199    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 18)
#  count :  200    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 19)
#  count :  201    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 20)
#  count :  202    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 21)
#  count :  203    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 22)
#  count :  204    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 23)
#  count :  205    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 24)
#  count :  206    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 25)
#  count :  207    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 26)
#  count :  208    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 27)
#  count :  209    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 28)
#  count :  210    ('file1000555.h5', '/data/local/NC2019MRI/train/file1000555.h5', 29)
#  count :  211    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 5)
#  count :  212    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 6)
#  count :  213    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 7)
#  count :  214    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 8)
#  count :  215    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 9)
#  count :  216    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 10)
#  count :  217    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 11)
#  count :  218    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 12)
#  count :  219    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 13)
#  count :  220    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 14)
#  count :  221    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 15)
#  count :  222    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 16)
#  count :  223    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 17)
#  count :  224    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 18)
#  count :  225    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 19)
#  count :  226    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 20)
#  count :  227    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 21)
#  count :  228    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 22)
#  count :  229    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 23)
#  count :  230    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 24)
#  count :  231    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 25)
#  count :  232    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 26)
#  count :  233    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 27)
#  count :  234    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 28)
#  count :  235    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 29)
#  count :  236    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 30)
#  count :  237    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 31)
#  count :  238    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 32)
#  count :  239    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 33)
#  count :  240    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 34)
#  count :  241    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 35)
#  count :  242    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 36)
#  count :  243    ('file1000528.h5', '/data/local/NC2019MRI/train/file1000528.h5', 37)
#  count :  244    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 5)
#  count :  245    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 6)
#  count :  246    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 7)
#  count :  247    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 8)
#  count :  248    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 9)
#  count :  249    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 10)
#  count :  250    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 11)
#  count :  251    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 12)
#  count :  252    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 13)
#  count :  253    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 14)
#  count :  254    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 15)
#  count :  255    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 16)
#  count :  256    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 17)
#  count :  257    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 18)
#  count :  258    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 19)
#  count :  259    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 20)
#  count :  260    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 21)
#  count :  261    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 22)
#  count :  262    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 23)
#  count :  263    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 24)
#  count :  264    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 25)
#  count :  265    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 26)
#  count :  266    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 27)
#  count :  267    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 28)
#  count :  268    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 29)
#  count :  269    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 30)
#  count :  270    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 31)
#  count :  271    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 32)
#  count :  272    ('file1000292.h5', '/data/local/NC2019MRI/train/file1000292.h5', 33)
#  count :  273    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 5)
#  count :  274    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 6)
#  count :  275    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 7)
#  count :  276    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 8)
#  count :  277    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 9)
#  count :  278    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 10)
#  count :  279    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 11)
#  count :  280    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 12)
#  count :  281    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 13)
#  count :  282    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 14)
#  count :  283    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 15)
#  count :  284    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 16)
#  count :  285    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 17)
#  count :  286    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 18)
#  count :  287    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 19)
#  count :  288    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 20)
#  count :  289    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 21)
#  count :  290    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 22)
#  count :  291    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 23)
#  count :  292    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 24)
#  count :  293    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 25)
#  count :  294    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 26)
#  count :  295    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 27)
#  count :  296    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 28)
#  count :  297    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 29)
#  count :  298    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 30)
#  count :  299    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 31)
#  count :  300    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 32)
#  count :  301    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 33)
#  count :  302    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 34)
#  count :  303    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 35)
#  count :  304    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 36)
#  count :  305    ('file1000625.h5', '/data/local/NC2019MRI/train/file1000625.h5', 37)
#  count :  306    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 5)
#  count :  307    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 6)
#  count :  308    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 7)
#  count :  309    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 8)
#  count :  310    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 9)
#  count :  311    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 10)
#  count :  312    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 11)
#  count :  313    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 12)
#  count :  314    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 13)
#  count :  315    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 14)
#  count :  316    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 15)
#  count :  317    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 16)
#  count :  318    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 17)
#  count :  319    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 18)
#  count :  320    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 19)
#  count :  321    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 20)
#  count :  322    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 21)
#  count :  323    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 22)
#  count :  324    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 23)
#  count :  325    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 24)
#  count :  326    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 25)
#  count :  327    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 26)
#  count :  328    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 27)
#  count :  329    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 28)
#  count :  330    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 29)
#  count :  331    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 30)
#  count :  332    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 31)
#  count :  333    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 32)
#  count :  334    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 33)
#  count :  335    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 34)
#  count :  336    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 35)
#  count :  337    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 36)
#  count :  338    ('file1000052.h5', '/data/local/NC2019MRI/train/file1000052.h5', 37)
#  count :  339    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 5)
#  count :  340    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 6)
#  count :  341    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 7)
#  count :  342    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 8)
#  count :  343    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 9)
#  count :  344    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 10)
#  count :  345    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 11)
#  count :  346    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 12)
#  count :  347    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 13)
#  count :  348    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 14)
#  count :  349    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 15)
#  count :  350    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 16)
#  count :  351    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 17)
#  count :  352    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 18)
#  count :  353    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 19)
#  count :  354    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 20)
#  count :  355    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 21)
#  count :  356    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 22)
#  count :  357    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 23)
#  count :  358    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 24)
#  count :  359    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 25)
#  count :  360    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 26)
#  count :  361    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 27)
#  count :  362    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 28)
#  count :  363    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 29)
#  count :  364    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 30)
#  count :  365    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 31)
#  count :  366    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 32)
#  count :  367    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 33)
#  count :  368    ('file1000267.h5', '/data/local/NC2019MRI/train/file1000267.h5', 34)
#  count :  369    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 5)
#  count :  370    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 6)
#  count :  371    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 7)
#  count :  372    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 8)
#  count :  373    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 9)
#  count :  374    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 10)
#  count :  375    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 11)
#  count :  376    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 12)
#  count :  377    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 13)
#  count :  378    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 14)
#  count :  379    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 15)
#  count :  380    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 16)
#  count :  381    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 17)
#  count :  382    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 18)
#  count :  383    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 19)
#  count :  384    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 20)
#  count :  385    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 21)
#  count :  386    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 22)
#  count :  387    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 23)
#  count :  388    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 24)
#  count :  389    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 25)
#  count :  390    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 26)
#  count :  391    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 27)
#  count :  392    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 28)
#  count :  393    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 29)
#  count :  394    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 30)
#  count :  395    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 31)
#  count :  396    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 32)
#  count :  397    ('file1000153.h5', '/data/local/NC2019MRI/train/file1000153.h5', 33)
#  count :  398    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 5)
#  count :  399    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 6)
#  count :  400    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 7)
#  count :  401    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 8)
#  count :  402    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 9)
#  count :  403    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 10)
#  count :  404    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 11)
#  count :  405    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 12)
#  count :  406    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 13)
#  count :  407    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 14)
#  count :  408    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 15)
#  count :  409    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 16)
#  count :  410    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 17)
#  count :  411    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 18)
#  count :  412    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 19)
#  count :  413    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 20)
#  count :  414    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 21)
#  count :  415    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 22)
#  count :  416    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 23)
#  count :  417    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 24)
#  count :  418    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 25)
#  count :  419    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 26)
#  count :  420    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 27)
#  count :  421    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 28)
#  count :  422    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 29)
#  count :  423    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 30)
#  count :  424    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 31)
#  count :  425    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 32)
#  count :  426    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 33)
#  count :  427    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 34)
#  count :  428    ('file1000308.h5', '/data/local/NC2019MRI/train/file1000308.h5', 35)
#
#
#
#
# TRAIN SET
#  count :  0    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 5)
#  count :  1    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 6)
#  count :  2    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 7)
#  count :  3    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 8)
#  count :  4    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 9)
#  count :  5    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 10)
#  count :  6    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 11)
#  count :  7    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 12)
#  count :  8    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 13)
#  count :  9    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 14)
#  count :  10    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 15)
#  count :  11    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 16)
#  count :  12    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 17)
#  count :  13    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 18)
#  count :  14    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 19)
#  count :  15    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 20)
#  count :  16    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 21)
#  count :  17    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 22)
#  count :  18    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 23)
#  count :  19    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 24)
#  count :  20    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 25)
#  count :  21    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 26)
#  count :  22    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 27)
#  count :  23    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 28)
#  count :  24    ('file1000107.h5', '/data/local/NC2019MRI/train/file1000107.h5', 29)
#  count :  25    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 5)
#  count :  26    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 6)
#  count :  27    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 7)
#  count :  28    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 8)
#  count :  29    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 9)
#  count :  30    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 10)
#  count :  31    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 11)
#  count :  32    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 12)
#  count :  33    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 13)
#  count :  34    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 14)
#  count :  35    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 15)
#  count :  36    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 16)
#  count :  37    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 17)
#  count :  38    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 18)
#  count :  39    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 19)
#  count :  40    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 20)
#  count :  41    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 21)
#  count :  42    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 22)
#  count :  43    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 23)
#  count :  44    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 24)
#  count :  45    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 25)
#  count :  46    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 26)
#  count :  47    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 27)
#  count :  48    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 28)
#  count :  49    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 29)
#  count :  50    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 30)
#  count :  51    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 31)
#  count :  52    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 32)
#  count :  53    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 33)
#  count :  54    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 34)
#  count :  55    ('file1000247.h5', '/data/local/NC2019MRI/train/file1000247.h5', 35)
#  count :  56    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 5)
#  count :  57    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 6)
#  count :  58    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 7)
#  count :  59    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 8)
#  count :  60    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 9)
#  count :  61    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 10)
#  count :  62    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 11)
#  count :  63    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 12)
#  count :  64    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 13)
#  count :  65    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 14)
#  count :  66    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 15)
#  count :  67    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 16)
#  count :  68    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 17)
#  count :  69    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 18)
#  count :  70    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 19)
#  count :  71    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 20)
#  count :  72    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 21)
#  count :  73    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 22)
#  count :  74    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 23)
#  count :  75    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 24)
#  count :  76    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 25)
#  count :  77    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 26)
#  count :  78    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 27)
#  count :  79    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 28)
#  count :  80    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 29)
#  count :  81    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 30)
#  count :  82    ('file1000496.h5', '/data/local/NC2019MRI/train/file1000496.h5', 31)
#  count :  83    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 5)
#  count :  84    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 6)
#  count :  85    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 7)
#  count :  86    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 8)
#  count :  87    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 9)
#  count :  88    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 10)
#  count :  89    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 11)
#  count :  90    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 12)
#  count :  91    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 13)
#  count :  92    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 14)
#  count :  93    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 15)
#  count :  94    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 16)
#  count :  95    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 17)
#  count :  96    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 18)
#  count :  97    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 19)
#  count :  98    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 20)
#  count :  99    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 21)
#  count :  100    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 22)
#  count :  101    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 23)
#  count :  102    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 24)
#  count :  103    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 25)
#  count :  104    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 26)
#  count :  105    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 27)
#  count :  106    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 28)
#  count :  107    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 29)
#  count :  108    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 30)
#  count :  109    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 31)
#  count :  110    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 32)
#  count :  111    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 33)
#  count :  112    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 34)
#  count :  113    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 35)
#  count :  114    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 36)
#  count :  115    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 37)
#  count :  116    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 38)
#  count :  117    ('file1000538.h5', '/data/local/NC2019MRI/train/file1000538.h5', 39)
#  count :  118    ('file1000323.h5', '/data/local/NC2019MRI/train/file1000323.h5', 5)
#  count :  119    ('file1000323.h5', '/data/local/NC2019MRI/train/file1000323.h5', 6)
#  count :  120    ('file1000323.h5', '/data/local/NC2019MRI/train/file1000323.h5', 7)
#  count :  121    ('file1000323.h5', '/data/local/NC2019MRI/train/file1000323.h5', 8)
#  count :  122    ('file1000323.h5', '/data/local/NC2019MRI/train/file1000323.h5', 9)
#  count :  123    ('file1000323.h5', '/data/local/NC2019MRI/train/file1000323.h5', 10)
#  count :  124    ('file1000323.h5', '/data/local/NC2019MRI/train/file1000323.h5', 11)
#  count :  125    ('file1000323.h5', '/data/local/NC2019MRI/train/file1000323.h5', 12)
#  count :  126    ('file1000323.h5', '/data/local/NC2019MRI/train/file1000323.h5', 13)
#  count :  127    ('file1000323.h5', '/data/local/NC2019MRI/train/file1000323.h5', 14)
#  count :  128    ('file1000323.h5', '/data/local/NC2019MRI/train/file1000323.h5', 15)
#  count :  129    ('file1000323.h5', '/data/local/NC2019MRI/train/file1000323.h5', 16)
#  count :  130    ('file1000323.h5', '/data/local/NC2019MRI/train/file1000323.h5', 17)
#  count :  131    ('file1000323.h5', '/data/local/NC2019MRI/train/file1000323.h5', 18)
# ...
#  count :  1521    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 9)
#  count :  1522    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 10)
#  count :  1523    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 11)
#  count :  1524    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 12)
#  count :  1525    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 13)
#  count :  1526    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 14)
#  count :  1527    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 15)
#  count :  1528    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 16)
#  count :  1529    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 17)
#  count :  1530    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 18)
#  count :  1531    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 19)
#  count :  1532    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 20)
#  count :  1533    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 21)
#  count :  1534    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 22)
#  count :  1535    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 23)
#  count :  1536    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 24)
#  count :  1537    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 25)
#  count :  1538    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 26)
#  count :  1539    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 27)
#  count :  1540    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 28)
#  count :  1541    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 29)
#  count :  1542    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 30)
#  count :  1543    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 31)
#  count :  1544    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 32)
#  count :  1545    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 33)
#  count :  1546    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 34)
#  count :  1547    ('file1000593.h5', '/data/local/NC2019MRI/train/file1000593.h5', 35)
#  count :  1548    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 5)
#  count :  1549    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 6)
#  count :  1550    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 7)
#  count :  1551    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 8)
#  count :  1552    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 9)
#  count :  1553    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 10)
#  count :  1554    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 11)
#  count :  1555    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 12)
#  count :  1556    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 13)
#  count :  1557    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 14)
#  count :  1558    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 15)
#  count :  1559    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 16)
#  count :  1560    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 17)
#  count :  1561    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 18)
#  count :  1562    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 19)
#  count :  1563    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 20)
#  count :  1564    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 21)
#  count :  1565    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 22)
#  count :  1566    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 23)
#  count :  1567    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 24)
#  count :  1568    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 25)
#  count :  1569    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 26)
#  count :  1570    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 27)
#  count :  1571    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 28)
#  count :  1572    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 29)
#  count :  1573    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 30)
#  count :  1574    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 31)
#  count :  1575    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 32)
#  count :  1576    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 33)
#  count :  1577    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 34)
#  count :  1578    ('file1000196.h5', '/data/local/NC2019MRI/train/file1000196.h5', 35)
#  count :  1579    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 5)
#  count :  1580    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 6)
#  count :  1581    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 7)
#  count :  1582    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 8)
#  count :  1583    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 9)
#  count :  1584    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 10)
#  count :  1585    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 11)
#  count :  1586    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 12)
#  count :  1587    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 13)
#  count :  1588    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 14)
#  count :  1589    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 15)
#  count :  1590    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 16)
#  count :  1591    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 17)
#  count :  1592    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 18)
#  count :  1593    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 19)
#  count :  1594    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 20)
#  count :  1595    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 21)
#  count :  1596    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 22)
#  count :  1597    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 23)
#  count :  1598    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 24)
#  count :  1599    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 25)
#  count :  1600    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 26)
#  count :  1601    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 27)
#  count :  1602    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 28)
#  count :  1603    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 29)
#  count :  1604    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 30)
#  count :  1605    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 31)
#  count :  1606    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 32)
#  count :  1607    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 33)
#  count :  1608    ('file1000206.h5', '/data/local/NC2019MRI/train/file1000206.h5', 34)
#  count :  1609    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 5)
#  count :  1610    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 6)
#  count :  1611    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 7)
#  count :  1612    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 8)
#  count :  1613    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 9)
#  count :  1614    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 10)
#  count :  1615    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 11)
#  count :  1616    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 12)
#  count :  1617    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 13)
#  count :  1618    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 14)
#  count :  1619    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 15)
#  count :  1620    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 16)
#  count :  1621    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 17)
#  count :  1622    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 18)
#  count :  1623    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 19)
#  count :  1624    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 20)
#  count :  1625    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 21)
#  count :  1626    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 22)
#  count :  1627    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 23)
#  count :  1628    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 24)
#  count :  1629    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 25)
#  count :  1630    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 26)
#  count :  1631    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 27)
#  count :  1632    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 28)
#  count :  1633    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 29)
#  count :  1634    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 30)
#  count :  1635    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 31)
#  count :  1636    ('file1000033.h5', '/data/local/NC2019MRI/train/file1000033.h5', 32)
#  count :  1637    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 5)
#  count :  1638    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 6)
#  count :  1639    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 7)
#  count :  1640    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 8)
#  count :  1641    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 9)
#  count :  1642    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 10)
#  count :  1643    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 11)
#  count :  1644    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 12)
#  count :  1645    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 13)
#  count :  1646    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 14)
#  count :  1647    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 15)
#  count :  1648    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 16)
#  count :  1649    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 17)
#  count :  1650    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 18)
#  count :  1651    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 19)
#  count :  1652    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 20)
#  count :  1653    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 21)
#  count :  1654    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 22)
#  count :  1655    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 23)
#  count :  1656    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 24)
#  count :  1657    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 25)
#  count :  1658    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 26)
#  count :  1659    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 27)
#  count :  1660    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 28)
#  count :  1661    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 29)
#  count :  1662    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 30)
#  count :  1663    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 31)
#  count :  1664    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 32)
#  count :  1665    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 33)
#  count :  1666    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 34)
#  count :  1667    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 35)
#  count :  1668    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 36)
#  count :  1669    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 37)
#  count :  1670    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 38)
#  count :  1671    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 39)
#  count :  1672    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 40)
#  count :  1673    ('file1000277.h5', '/data/local/NC2019MRI/train/file1000277.h5', 41)
#  count :  1674    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 5)
#  count :  1675    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 6)
#  count :  1676    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 7)
#  count :  1677    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 8)
#  count :  1678    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 9)
#  count :  1679    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 10)
#  count :  1680    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 11)
#  count :  1681    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 12)
#  count :  1682    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 13)
#  count :  1683    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 14)
#  count :  1684    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 15)
#  count :  1685    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 16)
#  count :  1686    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 17)
#  count :  1687    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 18)
#  count :  1688    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 19)
#  count :  1689    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 20)
#  count :  1690    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 21)
#  count :  1691    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 22)
#  count :  1692    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 23)
#  count :  1693    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 24)
#  count :  1694    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 25)
#  count :  1695    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 26)
#  count :  1696    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 27)
#  count :  1697    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 28)
#  count :  1698    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 29)
#  count :  1699    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 30)
#  count :  1700    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 31)
#  count :  1701    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 32)
#  count :  1702    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 33)
#  count :  1703    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 34)
#  count :  1704    ('file1000810.h5', '/data/local/NC2019MRI/train/file1000810.h5', 35)

# %%
######loads_train_data #######
if __name__ == '__main__':
    
    acc = 8
    cen_fract = 0.04
    seed = False # random masks for each slice 
    num_workers = 12 
    
    #
    train_dataset = MRIDataset(train_data_final['train'], acceleration=acc, center_fraction=cen_fract, use_seed=seed)
    train_loader = DataLoader(train_dataset, shuffle=True, batch_size=5, num_workers=num_workers) 
    
    validation_dataset = MRIDataset(train_data_final['val'], acceleration=acc, center_fraction=cen_fract, use_seed=seed)
    validation_loader = DataLoader(validation_dataset, shuffle=True, batch_size=5, num_workers=num_workers)

# %%
#cuda
import torch.optim as optim
device = 'cuda:0' if torch.cuda.is_available() else 'cpu' #'cpu'
torch.manual_seed(42)

# Now we can create a model
model = UnetModel(
    in_chans = 1,
    out_chans = 1,
    chans = 32,#640, #32
    num_pool_layers = 4,
    drop_prob = 0 ).to(device) # FirstModel().to(device)

# # we can also inspect its parameters
# print("Before training: \n", model.state_dict())

# %%
#set training


# set learning rate
print("HELOLOOO")
lr = 1e-4

#set number of epoches, i.e., number of times we iterate through the training set
epoches = 5

# # We use mean square error (MSELoss)
loss_fn = nn.MSELoss(reduction='mean').to(device)

# # Observe that all parameters are being optimized

optimiser = torch.optim.RMSprop(model.parameters(), lr=lr)

#Lists for plotting val/train SSIM/Loss/prEpoch
train_av_epoch_ssim_list = []
train_av_epoch_loss_list = []

val_av_epoch_ssim_list = []
val_av_epoch_loss_list = []

epoch_count = 0

#Model training
for epoch in range(epoches):
   
    model.train()
    
    train_total_loss = 0
    train_total_ssim = 0
    train_iterations= 0
    
    val_total_loss = 0
    val_total_ssim = 0
    val_iterations= 0
    
    #Training
    for data in train_loader:

        # set the model to training mode
        img_gt, img_und, _ = data
        
        #Reconstruction/prediction from undersampled data
        img_gt = img_gt.unsqueeze(1).to(device) 
        img_und.unsqueeze(1).to(device) 
        optimiser.zero_grad()
        y_pred = model(img_und.to(device))
        
        #calculate the loss from training data
        loss = loss_fn(img_gt.to(device), y_pred)
        loss.backward() 
        optimiser.step()
        
        #calculate total loss for epoch to generate average loss
        train_total_loss = train_total_loss + loss.item()
        
        # calculate total ssim value for epoch to generate average ssim
        ssim_value = ssim(img_gt.squeeze().cpu().numpy(),img_und.squeeze().cpu().numpy())
        train_total_ssim = train_total_ssim + ssim_value

        #count
        train_iterations = train_iterations +1
        
        
    train_av_ssim = train_total_ssim/train_iterations
    train_av_loss = train_total_loss/train_iterations
    
    train_av_epoch_ssim_list.append(train_av_ssim)
    train_av_epoch_loss_list.append(train_av_loss)
    
    
    
    #Validation 
    with torch.no_grad():
        #set to evaluation mode
        model.eval()
        for data in validation_loader:

            #from data loader
            img_gt, img_und, _ = data
            
            #Reconstruction/prediction from undersampled data
            img_gt = img_gt.unsqueeze(1).to(device) 
            img_und.unsqueeze(1).to(device) 
            optimiser.zero_grad()
            y_pred = model(img_und.to(device))
            
             #calculate the loss from validation data
            val_loss = loss_fn(img_gt.to(device), y_pred)
            optimiser.step()
            
            #calculate total loss for epoch to generate average loss
            val_total_loss = val_total_loss + loss.item()
        
            #calculate total ssim value for epoch to generate average ssim
            ssim_value = ssim(img_gt.squeeze().cpu().numpy(),img_und.squeeze().cpu().numpy())
            val_total_ssim = val_total_ssim + ssim_value
            
            #count
            val_iterations = val_iterations + 1
            
    val_av_ssim = val_total_ssim/val_iterations
    val_av_loss = val_total_loss/val_iterations
    
    val_av_epoch_ssim_list.append(val_av_ssim)
    val_av_epoch_loss_list.append(val_av_loss)
    
    epoch_count = epoch_count + 1

print("epoch: ", epoch_count,"train_av_epoch_ssim_list :", train_av_epoch_ssim_list)
print("epoch: ", epoch_count,"train_av_epoch_loss_list :", train_av_epoch_loss_list)
print("epoch: ", epoch_count,"val_av_epoch_ssim_list :", val_av_epoch_ssim_list)
print("epoch: ", epoch_count,"val_av_epoch_loss_list :", val_av_epoch_loss_list)
# Out:
# HELOLOOO
# /bham/modules/roots/neural-comp/2019-20/lib64/python3.6/site-packages/torch/nn/modules/loss.py:431: UserWarning: Using a target size (torch.Size([5, 1, 320, 320])) that is different to the input size (torch.Size([5, 1, 1, 320, 320])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /bham/modules/roots/neural-comp/2019-20/lib/python3.6/site-packages/ipykernel_launcher.py:103: UserWarning: DEPRECATED: skimage.measure.compare_ssim has been moved to skimage.metrics.structural_similarity. It will be removed from skimage.measure in version 0.18.
# /bham/modules/roots/neural-comp/2019-20/lib64/python3.6/site-packages/torch/nn/modules/loss.py:431: UserWarning: Using a target size (torch.Size([4, 1, 320, 320])) that is different to the input size (torch.Size([4, 1, 1, 320, 320])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# epoch:  5 train_av_epoch_ssim_list : [0.5070788772460066, 0.5081403094669188, 0.508308142400908, 0.5076245247788153, 0.5057758044515877]
# epoch:  5 train_av_epoch_loss_list : [0.05318961931048426, 0.04325197083749904, 0.042873976593755206, 0.04281432241682084, 0.04274141828903705]
# epoch:  5 val_av_epoch_ssim_list : [0.5002324091239398, 0.4982688949692566, 0.5000009100449121, 0.49296374649041225, 0.4979771707853145]
# epoch:  5 val_av_epoch_loss_list : [0.04178491607308388, 0.029868362471461296, 0.043396446853876114, 0.05467818304896355, 0.04899785667657852]

# %%
#VALIDATION VS TRAINING SSIM COMPARISON
plt.plot(range(len(train_av_epoch_ssim_list)), train_av_epoch_ssim_list,'r', label = "Av Train SSIM")
plt.plot(range(len(val_av_epoch_ssim_list)), val_av_epoch_ssim_list,'b', label = "Av Val SSIM")
plt.xlabel("epochs")
plt.ylabel("Av SSIM")
plt.legend()
plt.show()

# %%
#VALIDATION VS TRAINING LOSS COMPARISON
plt.plot(range(len(train_av_epoch_loss_list)), train_av_epoch_loss_list,'r', label = "Av Training loss")
plt.plot(range(len(val_av_epoch_loss_list)), val_av_epoch_loss_list,'b', label = "Av Val loss")
plt.xlabel("Epochs")

plt.legend()
plt.show()

# %%
torch.save(model,"unet_model_save.pkl")
# Out:
# /bham/modules/roots/neural-comp/2019-20/lib64/python3.6/site-packages/torch/serialization.py:256: UserWarning: Couldn't retrieve source code for container of type UnetModel. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /bham/modules/roots/neural-comp/2019-20/lib64/python3.6/site-packages/torch/serialization.py:256: UserWarning: Couldn't retrieve source code for container of type ConvBlock. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
